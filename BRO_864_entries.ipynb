# %%
import pandas as pd

# %%
data = pd.read_csv('BRO 2 (Zomato) Sort file.csv')

# %%
data.head()
# Out:
#                  Restaurant_Name  Locality           Sponsored  \
# 0  Lager Street - Lounge and Bar  Balewadi              Lounge
# 1                   Deewan Khana  Balewadi  Casual Dining, Bar
# 2       D'nozzo Chinese Food Hub  Balewadi  Takeaway, Delivery
# 3           Zura Sizzler Kitchen  Balewadi       Casual Dining
# 4                     Nirvighnam  Balewadi       Casual Dining
#
#    Ratings_out_of_5     Number of votes  \
# 0               4.0  Based on 168 votes
# 1               4.1          262  votes
# 2               3.7   Based on 66 votes
# 3               0.0                   0
# 4               3.6           81  votes
#
#                                        Cuisines Charges_for_two  \
# 0  Bar Food, Continental, Italian, North Indian          ₹1,500
# 1                        Seafood, Maharashtrian          ₹1,400
# 2                                       Chinese     Not Present
# 3                 Continental, Asian, Beverages          ₹1,500
# ...

# %%
data
# Out:
#                     Restaurant_Name  Locality           Sponsored  \
# 0     Lager Street - Lounge and Bar  Balewadi              Lounge
# 1                      Deewan Khana  Balewadi  Casual Dining, Bar
# 2          D'nozzo Chinese Food Hub  Balewadi  Takeaway, Delivery
# 3              Zura Sizzler Kitchen  Balewadi       Casual Dining
# 4                        Nirvighnam  Balewadi       Casual Dining
# ...                             ...       ...                 ...
# 1320                    Teera Farms     Wakad       Casual Dining
# 1321               Restro The Pasta     Wakad  Takeaway, Delivery
# 1322                Superman's Cafe     Wakad                Café
# 1323              Not Just Parathas     Wakad            Delivery
# 1324                     Southentic     Wakad            Delivery
#
#       Ratings_out_of_5     Number of votes  \
# 0                  4.0  Based on 168 votes
# 1                  4.1          262  votes
# ...

# %%
data.describe()
# Out:
#        Ratings_out_of_5
# count       1325.000000
# mean           3.066113
# std            1.200959
# min            0.000000
# 25%            3.000000
# 50%            3.400000
# 75%            3.700000
# max            4.900000

# %%
data.columns
# Out:
# Index(['Restaurant_Name', 'Locality', 'Sponsored', 'Ratings_out_of_5',
#        'Number of votes', 'Cuisines', 'Charges_for_two', 'payment_modes',
#        'Rest_timming', '5_star_review_percentage', '4_star_review_percentage',
#        '3_star_review_percentage', '2_star_review_percentage',
#        '1_star_review_percentage'],
#       dtype='object')

# %%
data.describe()
# Out:
#        Ratings_out_of_5
# count       1325.000000
# mean           3.066113
# std            1.200959
# min            0.000000
# 25%            3.000000
# 50%            3.400000
# 75%            3.700000
# max            4.900000

# %%
data1 = data['loc']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'loc'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-100-34d1098b305a> in <module>
# ----> 1 data1 = data['loc']
#
# ...

# %%
data1
# Out:
# 0                 The Westin, Mundhwa
# 1                 The Westin, Mundhwa
# 2       Conrad Pune, Bund Garden Road
# 3                 The Westin, Mundhwa
# 4             Vivanta Pune, Hinjewadi
#                     ...
# 5428                     Sinhgad Road
# 5429                      Viman Nagar
# 5430                           Pimpri
# 5431                    Sadashiv Peth
# 5432                 B.T. Kawade Road
# Name: loc, Length: 5433, dtype: object

# %%
data.count()
# Out:
# Restaurant_Name             1325
# Locality                    1325
# Sponsored                   1325
# Ratings_out_of_5            1325
# Number of votes             1325
# Cuisines                    1325
# Charges_for_two             1325
# payment_modes               1325
# Rest_timming                1325
# 5_star_review_percentage    1325
# 4_star_review_percentage    1325
# 3_star_review_percentage    1325
# 2_star_review_percentage    1325
# 1_star_review_percentage    1325
# dtype: int64

# %%
data.max()
# Out:
# Restaurant_Name                                                  eSSSetrra
# Locality                                                             Wakad
# Sponsored                                               Takeaway, Delivery
# Ratings_out_of_5                                                       4.9
# Number of votes                                       Na základě 230 hlasů
# Cuisines                                       Wraps, Fast Food, Beverages
# Charges_for_two                                                       ₹900
# payment_modes               Cash,Debit Cards and Digital Payments accepted
# Rest_timming                                                        Closed
# 5_star_review_percentage                                               98%
# 4_star_review_percentage                                                9%
# 3_star_review_percentage                                                9%
# ...

# %%
data.min()
# Out:
# Restaurant_Name                100 Rupis.com Burgers & More
# Locality                                           Balewadi
# Sponsored                                            Bakery
# Ratings_out_of_5                                          0
# Number of votes                                           0
# Cuisines                    American, Chinese, North Indian
# Charges_for_two                                 Not Present
# payment_modes                       Cash and Cards accepted
# Rest_timming                              10:15am – 11:45pm
# 5_star_review_percentage                                  0
# 4_star_review_percentage                                  0
# 3_star_review_percentage                                  0
# 2_star_review_percentage                                  0
# 1_star_review_percentage                                  0
# dtype: object

# %%
print(data.isnull().count())
# Out:
# Restaurant_Name             1325
# Locality                    1325
# Sponsored                   1325
# Ratings_out_of_5            1325
# Number of votes             1325
# Cuisines                    1325
# Charges_for_two             1325
# payment_modes               1325
# Rest_timming                1325
# 5_star_review_percentage    1325
# 4_star_review_percentage    1325
# 3_star_review_percentage    1325
# 2_star_review_percentage    1325
# 1_star_review_percentage    1325
# dtype: int64

# %%
balewadi = data.loc[:, ['Locality' = 'Balewadi', 'Ratings_out_of_5']]
# Out:
#   File "<ipython-input-106-34e61a90cdcb>", line 1
#     balewadi = data.loc[:, ['Locality' = 'Balewadi', 'Ratings_out_of_5']]
#                                        ^
# SyntaxError: invalid syntax

# %%
balewadi
# Out:
#                    Restaurant_Name  Locality           Sponsored  \
# 0    Lager Street - Lounge and Bar  Balewadi              Lounge
# 1                     Deewan Khana  Balewadi  Casual Dining, Bar
# 2         D'nozzo Chinese Food Hub  Balewadi  Takeaway, Delivery
# 3             Zura Sizzler Kitchen  Balewadi       Casual Dining
# 4                       Nirvighnam  Balewadi       Casual Dining
# ..                             ...       ...                 ...
# 100                 Jojo's Kitchen  Balewadi       Casual Dining
# 101               Blue Box Biryani  Balewadi            Delivery
# 102                    China Magic  Balewadi  Takeaway, Delivery
# 103                     Cafe Cream  Balewadi         Quick Bites
# 104               Cafe Creamy Nuts  Balewadi                Café
#
#      Ratings_out_of_5     Number of votes  \
# 0                 4.0  Based on 168 votes
# 1                 4.1          262  votes
# 2                 3.7   Based on 66 votes
# ...

# %%
new_dataset = data[['Locality','Ratings_out_of_5']]

# %%
new_dataset
# Out:
#       Locality  Ratings_out_of_5
# 0     Balewadi               4.0
# 1     Balewadi               4.1
# 2     Balewadi               3.7
# 3     Balewadi               0.0
# 4     Balewadi               3.6
# ...        ...               ...
# 1320     Wakad               0.0
# 1321     Wakad               0.0
# 1322     Wakad               0.0
# 1323     Wakad               0.0
# 1324     Wakad               0.0
#
# [1325 rows x 2 columns]

# %%
df9 = data.groupby('Locality')['Ratings_out_of_5'].sum()

# %%
df9
# Out:
# Locality
# Balewadi      295.5
# Baner        1114.2
# Bavdhan       420.1
# Hinjawadi    1065.4
# Wakad        1167.4
# Name: Ratings_out_of_5, dtype: float64

# %%
balewadi = data[(data.Locality.str.contains('Balewadi'))]
Baner = data[(data.Locality.str.contains('Baner'))]
Bavdhan = data[(data.Locality.str.contains('Bavdhan'))]
Hinjawadi = data[(data.Locality.str.contains('Hinjawadi'))]
Wakad = data[(data.Locality.str.contains('Wakad'))]

# %%
balewadi
# Out:
#                    Restaurant_Name  Locality           Sponsored  \
# 0    Lager Street - Lounge and Bar  Balewadi              Lounge
# 1                     Deewan Khana  Balewadi  Casual Dining, Bar
# 2         D'nozzo Chinese Food Hub  Balewadi  Takeaway, Delivery
# 3             Zura Sizzler Kitchen  Balewadi       Casual Dining
# 4                       Nirvighnam  Balewadi       Casual Dining
# ..                             ...       ...                 ...
# 100                 Jojo's Kitchen  Balewadi       Casual Dining
# 101               Blue Box Biryani  Balewadi            Delivery
# 102                    China Magic  Balewadi  Takeaway, Delivery
# 103                     Cafe Cream  Balewadi         Quick Bites
# 104               Cafe Creamy Nuts  Balewadi                Café
#
#      Ratings_out_of_5     Number of votes  \
# 0                 4.0  Based on 168 votes
# 1                 4.1          262  votes
# 2                 3.7   Based on 66 votes
# ...

# %%
df44
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5428    False
# 5429    False
# 5430    False
# 5431    False
# 5432    False
# Name: loc, Length: 5433, dtype: bool
