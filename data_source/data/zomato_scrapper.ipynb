# %% [markdown]
# https://www.zomato.com/pune
#
# https://www.zomato.com/pune/baner-restaurants

# %%
import csv
from bs4 import BeautifulSoup
from selenium import webdriver
from urllib.request import Request, urlopen
import requests
url ='https://www.zomato.com/pune/baner-restaurants'
headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64; rv:78.0) Gecko/20100101 Firefox/78.0'}
response = requests.get(url,headers=headers)
response

#webpage = urlopen(req).read()
res
#response = requests.get(url)
#response
# Out:
# <Response [200]>

# %%
driver = webdriver.Firefox(executable_path='/home/perman/Documents/geckodriver')

# %%
print(driver.title)

# %%
def get_url(search_term):
    """Generate a url from search term """
    template = 'https://www.zomato.com/pune/{}'
    search_term = search_term.replace(' ', '-')
    return template.format(search_term)

# %%
get_url('baner restaurants')
# Out:
# 'https://www.zomato.com/pune/baner-restaurants'

# %%
driver.get(url)

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
x = soup.find_all('div',{'class':'jumbo-tracker'})

# %%
len(x)
# Out:
# 31

# %%
data = x[25]

# %%
data
# Out:
# <div class="jumbo-tracker"><div class="sc-cpHetk ildhVw"><a class="sc-iuDHTM jcAyJb" href="/pune/mcdonalds-baner/order"><div class="s1isp7-1 gnNUmd sc-erNlkL ckipQt" height="24.8rem" width="100%"><div class="s1isp7-3 dqsEmh" src=""></div><img alt="Restaurant Card" class="s1isp7-5 hppEfq" loading="lazy" src="https://b.zmtcdn.com/data/pictures/chains/1/10571/c0ba9ec0f08684316b2552a8eb5a1ea8_o2_featured_v2.jpg?output-format=webp"/></div><div class="sc-jkCMRl jIlWJF"><p class="sc-1hez2tp-0 sc-crNyjn gWQWGU">₹50 OFF</p></div></a><a class="sc-ghsgMZ etFlYH" href="/pune/mcdonalds-baner/order"><div class="sc-kEmuub kKWLrZ"><p class="sc-1hez2tp-0 sc-bbkauy bPEDFQ">McDonald's</p></div><div class="sc-eitiEO dYeBxZ"><section class="lhdg1m-0 kqpxRE" value="4.1" width="max-content"><div class="lhdg1m-1 jgTktZ"><div class="lhdg1m-3 dAchCJ"><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E2374 ...

# %%
for item in soup.select('.cfsgiA'):
    print(item)
# Out:
# <div class="sc-1mo3ldo-0 sc-ilGAqu cfsgiA"><h1 class="sc-7kepeu-0 sc-beKmYL cCRIeZ">Baner Restaurants, Pune</h1></div>
# <div class="sc-1mo3ldo-0 sc-ilGAqu cfsgiA"><div class="sc-lkYwMk geoulx"><div class="sc-eFTCDY fkeZPr"><div class="jumbo-tracker"><div class="sc-jascpn cVAQtL"><a class="sc-gBGeja ixxpnu" href="/pune/oye-kiddan-baner/order"><div class="s1isp7-1 gnNUmd sc-cPUNzw kkLfIB" height="24.8rem" width="100%"><div class="s1isp7-3 cfbXfQ" src=""></div><img alt="Restaurant Card" class="s1isp7-5 bKaJwg" loading="lazy" src=""/></div><div class="sc-fpdzYq fFzPUF"><p class="sc-1hez2tp-0 sc-ksfqlt cKOBEw">Pro extra 15% OFF</p><p class="sc-1hez2tp-0 sc-ksfqlt jNTIyv">₹50 OFF</p></div></a><a class="sc-fwNAQS fUZaqx" href="/pune/oye-kiddan-baner/order"><div class="sc-eWIzRM knUMkw"><p class="sc-1hez2tp-0 sc-bDOcnW izylsP">Oye Kiddan</p></div><div class="sc-kecUPG leexcw"><section class="lhdg1m-0 kqpxRE" value="3.9" width="max-content"><div class="lhdg1m-1 jgTktZ"><div class="lhdg1m-3 dAchCJ"><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class ...
# <div class="sc-1mo3ldo-0 sc-ilGAqu cfsgiA"><div class="sc-lkYwMk geoulx"><div class="sc-eFTCDY fkeZPr"><div class="jumbo-tracker"><div class="sc-jascpn cVAQtL"><a class="sc-gBGeja ixxpnu" href="/pune/pind-punjab-baner/order"><div class="s1isp7-1 gnNUmd sc-cPUNzw kkLfIB" height="24.8rem" width="100%"><div class="s1isp7-3 cfbXfQ" src=""></div><img alt="Restaurant Card" class="s1isp7-5 bKaJwg" loading="lazy" src=""/></div><div class="sc-fpdzYq fFzPUF"><p class="sc-1hez2tp-0 sc-ksfqlt cKOBEw">Pro extra 10% OFF</p><p class="sc-1hez2tp-0 sc-ksfqlt jNTIyv">₹50 OFF</p></div></a><a class="sc-fwNAQS fUZaqx" href="/pune/pind-punjab-baner/order"><div class="sc-eWIzRM knUMkw"><p class="sc-1hez2tp-0 sc-bDOcnW izylsP">Pind Punjab</p></div><div class="sc-kecUPG leexcw"><section class="lhdg1m-0 kqpxRE" value="3.9" width="max-content"><div class="lhdg1m-1 jgTktZ"><div class="lhdg1m-3 dAchCJ"><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i cl ...
# <div class="sc-1mo3ldo-0 sc-ilGAqu cfsgiA"><div class="sc-lkYwMk geoulx"><div class="sc-eFTCDY fkeZPr"><div class="jumbo-tracker"><div class="sc-jascpn cVAQtL"><a class="sc-gBGeja ixxpnu" href="/pune/cheesiano-pizza-balewadi/order"><div class="s1isp7-1 gnNUmd sc-cPUNzw kkLfIB" height="24.8rem" width="100%"><div class="s1isp7-3 cfbXfQ" src=""></div><img alt="Restaurant Card" class="s1isp7-5 bKaJwg" loading="lazy" src=""/></div><div class="sc-fpdzYq fFzPUF"><p class="sc-1hez2tp-0 sc-ksfqlt cKOBEw">Pro extra 15% OFF</p><p class="sc-1hez2tp-0 sc-ksfqlt jNTIyv">₹50 OFF</p></div></a><a class="sc-fwNAQS fUZaqx" href="/pune/cheesiano-pizza-balewadi/order"><div class="sc-eWIzRM knUMkw"><p class="sc-1hez2tp-0 sc-bDOcnW izylsP">Cheesiano Pizza</p></div><div class="sc-kecUPG leexcw"><section class="lhdg1m-0 kqpxRE" value="3.6" width="max-content"><div class="lhdg1m-1 jgTktZ"><div class="lhdg1m-3 dAchCJ"><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></pa ...

# %%
results = soup.find_all('div',{"class":'sc-1mo3ldo-0 sc-bqjOQT fgttQZ'})
results
# Out:
# []

# %%
len(results)
# Out:
# 0

# %%
data.find('p','sc-1hez2tp-0 sc-jBoNkH cqGniC').get_text()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-f77036074d94> in <module>
# ----> 1 data.find('p','sc-1hez2tp-0 sc-jBoNkH cqGniC').get_text()
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
import csv
from bs4 import BeautifulSoup
from selenium import webdriver

# %%
import mechanize
br = mechanize.Browser()
br.set_handle_robots(False)

# %%
headers = {"User-Agent":"Mozilla/5.0 (platform; rv:geckoversion) Gecko/geckotrail Firefox/firefoxversion"}
#print(res.text)
#print(res.status_code)

# %%
headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64; rv:78.0) Gecko/20100101 Firefox/78.0'}
response = requests.get("https://www.zomato.com/pune/baner-restaurants",headers=headers)
response
# Out:
# <Response [200]>

# %%
url = 'https://www.zomato.com/pune/baner-restaurants'
#driver.get(url)

# %%
response = requests.get(url)
response
# Out:
# <Response [403]>

# %%
print(driver.title)
# Out:
# Baner Restaurants, Pune, Restaurants in Baner - Zomato

# %%
def get_url(search_term):
    """Generate a url from search term """
    template = 'https://www.amazon.com/s?k={}&ref=nb_sb_noss_1'
    search_term = search_term.replace(' ', '+')
    return template.format(search_term)

# %%
url = get_url('ultrawide monitor')
print(url)

# %%
driver.get(url)

# %%
robots.txt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-f1b9a783bd78> in <module>
# ----> 1 robots.txt
#
# NameError: name 'robots' is not defined

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
results = soup.find_all('div',{"class":'jumbo-tracker'})
results
# Out:
# [<div class="jumbo-tracker"><div class="sc-jptPkM NRDZk"><a class="sc-ddcOto harCkj" href="/pune/momo-co-balewadi/order"><div class="s1isp7-1 gnNUmd sc-dzVpKk gkVhHs" height="24.8rem" width="100%"><div class="s1isp7-3 dqsEmh" src=""></div><img alt="Restaurant Card" class="s1isp7-5 hppEfq" loading="lazy" src="https://b.zmtcdn.com/data/pictures/chains/9/19407379/047b0a72258dbe926549d48db5d38f58_o2_featured_v2.jpg?output-format=webp"/></div><div class="sc-dHaUqb bljWID"><p class="sc-1hez2tp-0 sc-fcTNbh dNotRa">₹50 OFF</p></div></a><a class="sc-hdNmWC uicqY" href="/pune/momo-co-balewadi/order"><div class="sc-kJdAmE dncqIB"><p class="sc-1hez2tp-0 sc-jBoNkH cqGniC">Momo &amp; Co.</p></div><div class="sc-ghUbLI bqKqCV"><section class="lhdg1m-0 kqpxRE" value="3.9" width="max-content"><div class="lhdg1m-1 jgTktZ"><div class="lhdg1m-3 dAchCJ"><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-6 HpiHL" color= ...
#  <div class="jumbo-tracker"><div class="sc-jptPkM NRDZk"><a class="sc-ddcOto harCkj" href="/pune/kfc-baner/order"><div class="s1isp7-1 gnNUmd sc-dzVpKk gkVhHs" height="24.8rem" width="100%"><div class="s1isp7-3 dqsEmh" src=""></div><img alt="Restaurant Card" class="s1isp7-5 hppEfq" loading="lazy" src="https://b.zmtcdn.com/data/pictures/chains/4/10624/9410759d611db9c62c3acc23c1f27e06_o2_featured_v2.jpg?output-format=webp"/></div><div class="sc-dHaUqb bljWID"></div></a><a class="sc-hdNmWC uicqY" href="/pune/kfc-baner/order"><div class="sc-kJdAmE dncqIB"><p class="sc-1hez2tp-0 sc-jBoNkH cqGniC">KFC</p></div><div class="sc-ghUbLI bqKqCV"><section class="lhdg1m-0 kqpxRE" value="4.1" width="max-content"><div class="lhdg1m-1 jgTktZ"><div class="lhdg1m-3 dAchCJ"><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class ...
#  <div class="jumbo-tracker"><div class="sc-jptPkM NRDZk"><a class="sc-ddcOto harCkj" href="/pune/cheesiano-pizza-balewadi/order"><div class="s1isp7-1 gnNUmd sc-dzVpKk gkVhHs" height="24.8rem" width="100%"><div class="s1isp7-3 dqsEmh" src=""></div><img alt="Restaurant Card" class="s1isp7-5 hppEfq" loading="lazy" src="https://b.zmtcdn.com/data/pictures/chains/9/6507609/9b51e3f85654b9588558b2a11ece5d27_o2_featured_v2.jpg?output-format=webp"/></div><div class="sc-dHaUqb bljWID"><p class="sc-1hez2tp-0 sc-fcTNbh kuOQeY">Pro extra 15% OFF</p><p class="sc-1hez2tp-0 sc-fcTNbh dNotRa">₹50 OFF</p></div></a><a class="sc-hdNmWC uicqY" href="/pune/cheesiano-pizza-balewadi/order"><div class="sc-kJdAmE dncqIB"><p class="sc-1hez2tp-0 sc-jBoNkH cqGniC">Cheesiano Pizza</p></div><div class="sc-ghUbLI bqKqCV"><section class="lhdg1m-0 kqpxRE" value="3.6" width="max-content"><div class="lhdg1m-1 jgTktZ"><div class="lhdg1m-3 dAchCJ"><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-r ...
#  <div class="jumbo-tracker"><div class="sc-jptPkM NRDZk"><a class="sc-ddcOto harCkj" href="/pune/mcdonalds-baner/order"><div class="s1isp7-1 gnNUmd sc-dzVpKk gkVhHs" height="24.8rem" width="100%"><div class="s1isp7-3 dqsEmh" src=""></div><img alt="Restaurant Card" class="s1isp7-5 hppEfq" loading="lazy" src="https://b.zmtcdn.com/data/pictures/chains/1/10571/98f61bae7f08ccd13f1522c72700c536_o2_featured_v2.jpg?output-format=webp"/></div><div class="sc-dHaUqb bljWID"><p class="sc-1hez2tp-0 sc-fcTNbh dNotRa">₹50 OFF</p></div></a><a class="sc-hdNmWC uicqY" href="/pune/mcdonalds-baner/order"><div class="sc-kJdAmE dncqIB"><p class="sc-1hez2tp-0 sc-jBoNkH cqGniC">McDonald's</p></div><div class="sc-ghUbLI bqKqCV"><section class="lhdg1m-0 kqpxRE" value="4.1" width="max-content"><div class="lhdg1m-1 jgTktZ"><div class="lhdg1m-3 dAchCJ"><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744 ...
#  <div class="jumbo-tracker"><div class="sc-jptPkM NRDZk"><a class="sc-ddcOto harCkj" href="/pune/mr-chopsticks-baner/order"><div class="s1isp7-1 gnNUmd sc-dzVpKk gkVhHs" height="24.8rem" width="100%"><div class="s1isp7-3 dqsEmh" src=""></div><img alt="Restaurant Card" class="s1isp7-5 hppEfq" loading="lazy" src="https://b.zmtcdn.com/data/pictures/9/19177689/436c52a7f557265b3b46b67e3f261b21_o2_featured_v2.jpg?output-format=webp"/></div><div class="sc-dHaUqb bljWID"><p class="sc-1hez2tp-0 sc-fcTNbh kuOQeY">Pro extra 20% OFF</p><p class="sc-1hez2tp-0 sc-fcTNbh dNotRa">₹50 OFF</p></div></a><a class="sc-hdNmWC uicqY" href="/pune/mr-chopsticks-baner/order"><div class="sc-kJdAmE dncqIB"><p class="sc-1hez2tp-0 sc-jBoNkH cqGniC">Mr. Chopsticks</p></div><div class="sc-ghUbLI bqKqCV"><section class="lhdg1m-0 kqpxRE" value="3.9" width="max-content"><div class="lhdg1m-1 jgTktZ"><div class="lhdg1m-3 dAchCJ"><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></p ...
#  <div class="jumbo-tracker"><div class="sc-jptPkM NRDZk"><a class="sc-ddcOto harCkj" href="/pune/the-irani-cafe-baner/order"><div class="s1isp7-1 gnNUmd sc-dzVpKk gkVhHs" height="24.8rem" width="100%"><div class="s1isp7-3 dqsEmh" src=""></div><img alt="Restaurant Card" class="s1isp7-5 hppEfq" loading="lazy" src="https://b.zmtcdn.com/data/pictures/3/19188563/a9b62942b694c2caf8547f50fee65a3a_o2_featured_v2.jpg?output-format=webp"/></div><div class="sc-dHaUqb bljWID"><p class="sc-1hez2tp-0 sc-fcTNbh dNotRa">₹50 OFF</p></div></a><a class="sc-hdNmWC uicqY" href="/pune/the-irani-cafe-baner/order"><div class="sc-kJdAmE dncqIB"><p class="sc-1hez2tp-0 sc-jBoNkH cqGniC">The Irani Cafe</p></div><div class="sc-ghUbLI bqKqCV"><section class="lhdg1m-0 kqpxRE" value="4.2" width="max-content"><div class="lhdg1m-1 jgTktZ"><div class="lhdg1m-3 dAchCJ"><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" colo ...
#  <div class="jumbo-tracker"><div class="sc-jptPkM NRDZk"><a class="sc-ddcOto harCkj" href="/pune/zippyfeed-wakad/order"><div class="s1isp7-1 gnNUmd sc-dzVpKk gkVhHs" height="24.8rem" width="100%"><div class="s1isp7-3 cfbXfQ" src=""></div><img alt="Restaurant Card" class="s1isp7-5 bKaJwg" loading="lazy" src=""/></div><div class="sc-dHaUqb bljWID"><p class="sc-1hez2tp-0 sc-fcTNbh dNotRa">₹50 OFF</p></div></a><a class="sc-hdNmWC uicqY" href="/pune/zippyfeed-wakad/order"><div class="sc-kJdAmE dncqIB"><p class="sc-1hez2tp-0 sc-jBoNkH cqGniC">ZippyFeed</p></div><div class="sc-gkfylT ejPjnA"><div class="sc-2gamf4-0 fSJGVb" font-size="1.2rem" type="tag">NEWLY OPENED</div></div><p class="sc-1hez2tp-0 sc-fPbjcq dxJMBd">Fast Food, Rolls, Burger, Momos, Biryani</p><p class="sc-1hez2tp-0 sc-FAiZp gEhaLS"><span class="sc-dAWfgX gpTZdu">₹100 for one</span><span class="sc-fPEBxH ixrmsZ"></span>43 min</p></a><p class="sc-1hez2tp-0 sc-kQZOhr JuunF">Promoted</p><span class="sc-kSpkgE epusoB"> </span></div></div>,
#  <div class="jumbo-tracker"><div class="sc-jptPkM NRDZk"><a class="sc-ddcOto harCkj" href="/pune/theobroma-balewadi/order"><div class="s1isp7-1 gnNUmd sc-dzVpKk gkVhHs" height="24.8rem" width="100%"><div class="s1isp7-3 cfbXfQ" src=""></div><img alt="Restaurant Card" class="s1isp7-5 bKaJwg" loading="lazy" src=""/></div><div class="sc-dHaUqb bljWID"><p class="sc-1hez2tp-0 sc-fcTNbh dNotRa">₹50 OFF</p></div></a><a class="sc-hdNmWC uicqY" href="/pune/theobroma-balewadi/order"><div class="sc-kJdAmE dncqIB"><p class="sc-1hez2tp-0 sc-jBoNkH cqGniC">Theobroma</p></div><div class="sc-ghUbLI bqKqCV"><section class="lhdg1m-0 kqpxRE" value="4.4" width="max-content"><div class="lhdg1m-1 jgTktZ"><div class="lhdg1m-3 dAchCJ"><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18"  ...
#  <div class="jumbo-tracker"><div class="sc-jptPkM NRDZk"><a class="sc-ddcOto harCkj" href="/pune/wow-momo-baner/order"><div class="s1isp7-1 gnNUmd sc-dzVpKk gkVhHs" height="24.8rem" width="100%"><div class="s1isp7-3 cfbXfQ" src=""></div><img alt="Restaurant Card" class="s1isp7-5 bKaJwg" loading="lazy" src=""/></div><div class="sc-dHaUqb bljWID"><p class="sc-1hez2tp-0 sc-fcTNbh dNotRa">₹50 OFF</p></div></a><a class="sc-hdNmWC uicqY" href="/pune/wow-momo-baner/order"><div class="sc-kJdAmE dncqIB"><p class="sc-1hez2tp-0 sc-jBoNkH cqGniC">Wow! Momo</p></div><div class="sc-ghUbLI bqKqCV"><section class="lhdg1m-0 kqpxRE" value="3.9" width="max-content"><div class="lhdg1m-1 jgTktZ"><div class="lhdg1m-3 dAchCJ"><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-6 HpiHL" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img ...

# %%
#results

# %%
len(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-b962231df7f8> in <module>
# ----> 1 len(results)
#
# NameError: name 'results' is not defined

# %%
data = results[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-d1692dfe14fa> in <module>
# ----> 1 data = results[1]
#
# NameError: name 'results' is not defined

# %%
#data

# %%
class="sc-1hez2tp-0 sc-cBqwIa eKlCMH"
class="sc-1hez2tp-0 sc-cBqwIa eKlCMH"
sc-ikTlrC bVjEjN
sc-1hez2tp-0 sc-jBoNkH cqGniC

# %%
data.find('p','sc-1hez2tp-0 sc-jBoNkH cqGniC').get_text()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-f77036074d94> in <module>
# ----> 1 data.find('p','sc-1hez2tp-0 sc-jBoNkH cqGniC').get_text()
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
atag = data.find('a')
url = 'https://www.zomato.com' + atag.get('href')
url
# Out:
# 'https://www.zomato.com/pune/baner-restaurants?place_name=Baner&dishv2_id=d9452952b432b35d1019ada01cedce7f_2'

# %%
name = data.find_all('p')[1].get_text()
name
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-57-1728cb5ea52e> in <module>
# ----> 1 name = data.find_all('p')[1].get_text()
#       2 name
#
# IndexError: list index out of range

# %%
data.find_all('p')
# Out:
# [<p class="sc-1hez2tp-0 sc-bPjRNf durcdf">Pizza</p>]

# %%
ratings = data.find('p','sc-1hez2tp-0 lhdg1m-2 dgzDPB').get_text()
ratings
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-da7df1195f50> in <module>
# ----> 1 ratings = data.find('p','sc-1hez2tp-0 lhdg1m-2 dgzDPB').get_text()
#       2 ratings
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
Cuisine = data.find('p', 'sc-1hez2tp-0 sc-hfyccY ijjRYO').get_text()
Cuisine
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-48cd8d4d9dd9> in <module>
# ----> 1 Cuisine = data.find('p', 'sc-1hez2tp-0 sc-hfyccY ijjRYO').get_text()
#       2 Cuisine
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
price_for_1 = data.find('p','sc-1hez2tp-0 sc-iIQDRA iplMES').get_text()
price_for_1
# Out:
# '₹150 for one21 min'

# %%
Delivery_Reviews = data.find('p','sc-1hez2tp-0 lhdg1m-8 hztxkg').get_text()
Delivery_Reviews
# Out:
# '(1,789 Delivery Reviews)'

# %%
off_given = data.find('p', 'sc-1hez2tp-0 sc-enOJk dUYOBQ').get_text() 
off_given
# Out:
# '₹50 OFF'

# %%
x = data.find('a',{'class':"sc-kDhYZr kwNaxi"})
x

# %%
data = soup.find_all('div',{'class','sc-1mo3ldo-0 sc-jHXLhC iALLUE'})

# %%
#for page in range(0,1):
#    print(page_no)
#    response = requests.get("https://www.zomato.com/pune/baner-restaurants?page={0}".format(page_no), headers=headers)
#    content = response.content
#    soup = BeautifulSoup(content, "html.parser")
#    search_list = soup.find_all("div", {'id': 'orig-search-list'})
#    list_content = search_list[0].find_all("div", {'class': 'content'})
#

# %%
import csv
from bs4 import BeautifulSoup
from selenium import webdriver
import requests
from urllib.request import Request, urlopen

from time import sleep
from random import randint

import mechanize
br = mechanize.Browser()
br.set_handle_robots(False)

#res = requests.get('https://ieeexplore.ieee.org/search/searchresult.jsp?newsearch=true&queryText=image%20processing')

#print(res.text)
#print(res.status_code)

url ='https://www.zomato.com/pune/baner-restaurants'
header={'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64; rv:78.0) Gecko/20100101 Firefox/78.0'}
res = requests.get(url,headers=header)

lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
match=False
while(match==False):
    lastCount = lenOfPage
    time.sleep(5)
    lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
    if lastCount==lenOfPage:
        match=True



def get_url(search_term):
    template = 'https://www.zomato.com/pune/{}'
    search_term = search_term.replace(' ', '-')
    url = template.format(search_term)
    
    
    return url

def extract_record(data):
    atag = data.find('a')
    try:
        url = 'https://www.zomato.com' + atag.get('href')
    except:
        url = " "
    try:
        name = data.find('p','sc-1hez2tp-0 sc-jBoNkH cqGniC').get_text()
    except:
        name = " "
    
    try:
        ratings = data.find('p','sc-1hez2tp-0 lhdg1m-2 dgzDPB').get_text()

    except:
        ratings = " "
    
    try:
        price_for_1 = data.find('p','sc-1hez2tp-0 sc-iIQDRA iplMES').get_text()

    except:
        price_for_1 = " "
    
    try:
        Delivery_Reviews = data.find('p','sc-1hez2tp-0 lhdg1m-8 hztxkg').get_text()

    except:
        Delivery_Reviews = " "
        
    try:
        off_given = data.find('p', 'sc-1hez2tp-0 sc-enOJk dUYOBQ').get_text() 

    except:
        off_given = " "
        
    try:
        Cuisine = data.find('p', 'sc-1hez2tp-0 sc-hfyccY ijjRYO').get_text()

    except:
        Cuisine = " "
    
    result = (url,name,ratings,price_for_1,Delivery_Reviews,off_given,Cuisine)
    
    return result

def main(search_term):
    browser = webdriver.Firefox(executable_path='/home/perman/Documents/geckodriver')

    
    records = []
    url = get_url(search_term)
    
    
    

    
    
    for page in range(1,3):
        driver.get(url.format(page))
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        results =soup.find_all('div',{"class":'jumbo-tracker'})
        sleep(randint(20,30))
        
        for data in results:
            record = extract_record(data)
            if record:
                records.append(record)
                
    driver.close()
    
    with open('results_zomato1.csv', 'w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow(['url','name','ratings','price_for_1','Delivery_Reviews','off_given','Cuisine'])
        writer.writerows(records)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-d56bdc5cfcc2> in <module>
#      21 res = requests.get(url,headers=header)
#      22
# ---> 23 lenOfPage = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
#      24 match=False
#      25 while(match==False):
#
# NameError: name 'browser' is not defined

# %%
main('baner restaurants')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-2df54d3913aa> in <module>
# ----> 1 main('baner restaurants')
#
# <ipython-input-2-b368c225ca17> in main(search_term)
#      85         soup = BeautifulSoup(driver.page_source, 'html.parser')
#      86         results =soup.find_all('div',{"class":'jumbo-tracker'})
# ---> 87         sleep(randint(20,30))
#      88
#      89         for data in results:
#
# KeyboardInterrupt:

# %%
def get_url(search_term):
    template = 'https://www.zomato.com/pune/{}'
    search_term = search_term.replace(' ', '-')
    url = template.format(search_term)
    
    print(url)
    return url
main('baner restaurants')
# Out:
# https://www.zomato.com/pune/baner-restaurants

# %% [markdown]
# ### github code

# %%
import requests
from bs4 import BeautifulSoup
import pandas
import csv
import re

headers = {"User-Agent":"Mozilla/5.0 (platform; rv:geckoversion) Gecko/geckotrail Firefox/firefoxversion"}
page_no = 1
list_restaurants =[]

for page in range(1,3):
    print(page_no)
    url = "https://www.zomato.com/pune/restaurants?page={0}"
    driver.get(url.format(page))
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    search_list = soup.find_all("div", {'id': 'orig-search-list'})
    list_content = search_list[0].find_all("div", {'class': 'content'})
    for i in range(0,15):
        res_name = list_content[i].find("a", {'data-result-type': 'ResCard_Name'})
        locality = list_content[i].find("b")
        ratings = list_content[i].find("div", {'data-variation': 'mini inverted'})
        if ratings is None:
            continue
        rest6 = list_content[i].find_all("div", {'class': 'search-page-text clearfix row'})
        rest7 = rest6[0].find_all("span", {'class': 'col-s-11 col-m-12 nowrap pl0'})
        rest8 = rest7[0].find_all("a")
        cuisines = [e.string for e in rest8]
        cost_for_two = rest6[0].find("span", {'class': 'col-s-11 col-m-12 pl0'})
        if cost_for_two is None:
            continue
        votes = list_content[i].find("span", {'class': re.compile(r'rating-votes-div*')})
        if votes is None:
            continue
        dataframe ={}
        dataframe["rest_name"] = res_name.string.replace('\n', ' ')
        dataframe["locality"] = locality.string.replace('\n', ' ')
        dataframe["rating"] = ratings.string.replace('\n', ' ')
        dataframe["cuisines"] = cuisines
        dataframe["cost_for_two"] = cost_for_two.string[1:]
        dataframe["votes"] = votes.string.split()[0]
        list_restaurants.append(dataframe)
    page_no+=1
    
df = pandas.DataFrame(list_restaurants)
df.to_csv("zomato_aurants.csv")

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
import re
#import urllib.request

# %%
driver = webdriver.Firefox(executable_path='/home/perman/Documents/geckodriver')

# %%
url = 'https://www.zomato.com/pune/baner-restaurants'
driver.get(url)

# %%
#Used headers/agent as the request timed out and asking for agent. Using following code you can fake the agent.
headers = {"User-Agent":"Mozilla/5.0 (platform; rv:geckoversion) Gecko/geckotrail Firefox/firefoxversion"}

# %%
soup = BeautifulSoup(driver.page_source,'html.parser')

# %%
data =soup.find_all('div',{"class":'jumbo-tracker'})

# %%
data
# Out:
# [<div class="jumbo-tracker"><div class="sc-jptPkM NRDZk"><a class="sc-ddcOto harCkj" href="/pune/momo-co-balewadi/order"><div class="s1isp7-1 gnNUmd sc-dzVpKk gkVhHs" height="24.8rem" width="100%"><div class="s1isp7-3 dqsEmh" src=""></div><img alt="Restaurant Card" class="s1isp7-5 hppEfq" loading="lazy" src="https://b.zmtcdn.com/data/pictures/chains/9/19407379/047b0a72258dbe926549d48db5d38f58_o2_featured_v2.jpg?output-format=webp"/></div><div class="sc-dHaUqb bljWID"><p class="sc-1hez2tp-0 sc-fcTNbh dNotRa">₹50 OFF</p></div></a><a class="sc-hdNmWC uicqY" href="/pune/momo-co-balewadi/order"><div class="sc-kJdAmE dncqIB"><p class="sc-1hez2tp-0 sc-jBoNkH cqGniC">Momo &amp; Co.</p></div><div class="sc-ghUbLI bqKqCV"><section class="lhdg1m-0 kqpxRE" value="3.9" width="max-content"><div class="lhdg1m-1 jgTktZ"><div class="lhdg1m-3 dAchCJ"><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-6 HpiHL" color= ...
#  <div class="jumbo-tracker"><div class="sc-jptPkM NRDZk"><a class="sc-ddcOto harCkj" href="/pune/kfc-baner/order"><div class="s1isp7-1 gnNUmd sc-dzVpKk gkVhHs" height="24.8rem" width="100%"><div class="s1isp7-3 dqsEmh" src=""></div><img alt="Restaurant Card" class="s1isp7-5 hppEfq" loading="lazy" src="https://b.zmtcdn.com/data/pictures/chains/4/10624/9410759d611db9c62c3acc23c1f27e06_o2_featured_v2.jpg?output-format=webp"/></div><div class="sc-dHaUqb bljWID"></div></a><a class="sc-hdNmWC uicqY" href="/pune/kfc-baner/order"><div class="sc-kJdAmE dncqIB"><p class="sc-1hez2tp-0 sc-jBoNkH cqGniC">KFC</p></div><div class="sc-ghUbLI bqKqCV"><section class="lhdg1m-0 kqpxRE" value="4.1" width="max-content"><div class="lhdg1m-1 jgTktZ"><div class="lhdg1m-3 dAchCJ"><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class ...
#  <div class="jumbo-tracker"><div class="sc-jptPkM NRDZk"><a class="sc-ddcOto harCkj" href="/pune/cheesiano-pizza-balewadi/order"><div class="s1isp7-1 gnNUmd sc-dzVpKk gkVhHs" height="24.8rem" width="100%"><div class="s1isp7-3 dqsEmh" src=""></div><img alt="Restaurant Card" class="s1isp7-5 hppEfq" loading="lazy" src="https://b.zmtcdn.com/data/pictures/chains/9/6507609/9b51e3f85654b9588558b2a11ece5d27_o2_featured_v2.jpg?output-format=webp"/></div><div class="sc-dHaUqb bljWID"><p class="sc-1hez2tp-0 sc-fcTNbh kuOQeY">Pro extra 15% OFF</p><p class="sc-1hez2tp-0 sc-fcTNbh dNotRa">₹50 OFF</p></div></a><a class="sc-hdNmWC uicqY" href="/pune/cheesiano-pizza-balewadi/order"><div class="sc-kJdAmE dncqIB"><p class="sc-1hez2tp-0 sc-jBoNkH cqGniC">Cheesiano Pizza</p></div><div class="sc-ghUbLI bqKqCV"><section class="lhdg1m-0 kqpxRE" value="3.6" width="max-content"><div class="lhdg1m-1 jgTktZ"><div class="lhdg1m-3 dAchCJ"><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-r ...
#  <div class="jumbo-tracker"><div class="sc-jptPkM NRDZk"><a class="sc-ddcOto harCkj" href="/pune/mcdonalds-baner/order"><div class="s1isp7-1 gnNUmd sc-dzVpKk gkVhHs" height="24.8rem" width="100%"><div class="s1isp7-3 dqsEmh" src=""></div><img alt="Restaurant Card" class="s1isp7-5 hppEfq" loading="lazy" src="https://b.zmtcdn.com/data/pictures/chains/1/10571/98f61bae7f08ccd13f1522c72700c536_o2_featured_v2.jpg?output-format=webp"/></div><div class="sc-dHaUqb bljWID"><p class="sc-1hez2tp-0 sc-fcTNbh dNotRa">₹50 OFF</p></div></a><a class="sc-hdNmWC uicqY" href="/pune/mcdonalds-baner/order"><div class="sc-kJdAmE dncqIB"><p class="sc-1hez2tp-0 sc-jBoNkH cqGniC">McDonald's</p></div><div class="sc-ghUbLI bqKqCV"><section class="lhdg1m-0 kqpxRE" value="4.1" width="max-content"><div class="lhdg1m-1 jgTktZ"><div class="lhdg1m-3 dAchCJ"><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744 ...
#  <div class="jumbo-tracker"><div class="sc-jptPkM NRDZk"><a class="sc-ddcOto harCkj" href="/pune/mr-chopsticks-baner/order"><div class="s1isp7-1 gnNUmd sc-dzVpKk gkVhHs" height="24.8rem" width="100%"><div class="s1isp7-3 dqsEmh" src=""></div><img alt="Restaurant Card" class="s1isp7-5 hppEfq" loading="lazy" src="https://b.zmtcdn.com/data/pictures/9/19177689/436c52a7f557265b3b46b67e3f261b21_o2_featured_v2.jpg?output-format=webp"/></div><div class="sc-dHaUqb bljWID"><p class="sc-1hez2tp-0 sc-fcTNbh kuOQeY">Pro extra 20% OFF</p><p class="sc-1hez2tp-0 sc-fcTNbh dNotRa">₹50 OFF</p></div></a><a class="sc-hdNmWC uicqY" href="/pune/mr-chopsticks-baner/order"><div class="sc-kJdAmE dncqIB"><p class="sc-1hez2tp-0 sc-jBoNkH cqGniC">Mr. Chopsticks</p></div><div class="sc-ghUbLI bqKqCV"><section class="lhdg1m-0 kqpxRE" value="3.9" width="max-content"><div class="lhdg1m-1 jgTktZ"><div class="lhdg1m-3 dAchCJ"><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></p ...
#  <div class="jumbo-tracker"><div class="sc-jptPkM NRDZk"><a class="sc-ddcOto harCkj" href="/pune/the-irani-cafe-baner/order"><div class="s1isp7-1 gnNUmd sc-dzVpKk gkVhHs" height="24.8rem" width="100%"><div class="s1isp7-3 dqsEmh" src=""></div><img alt="Restaurant Card" class="s1isp7-5 hppEfq" loading="lazy" src="https://b.zmtcdn.com/data/pictures/3/19188563/a9b62942b694c2caf8547f50fee65a3a_o2_featured_v2.jpg?output-format=webp"/></div><div class="sc-dHaUqb bljWID"><p class="sc-1hez2tp-0 sc-fcTNbh dNotRa">₹50 OFF</p></div></a><a class="sc-hdNmWC uicqY" href="/pune/the-irani-cafe-baner/order"><div class="sc-kJdAmE dncqIB"><p class="sc-1hez2tp-0 sc-jBoNkH cqGniC">The Irani Cafe</p></div><div class="sc-ghUbLI bqKqCV"><section class="lhdg1m-0 kqpxRE" value="4.2" width="max-content"><div class="lhdg1m-1 jgTktZ"><div class="lhdg1m-3 dAchCJ"><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" colo ...
#  <div class="jumbo-tracker"><div class="sc-jptPkM NRDZk"><a class="sc-ddcOto harCkj" href="/pune/zippyfeed-wakad/order"><div class="s1isp7-1 gnNUmd sc-dzVpKk gkVhHs" height="24.8rem" width="100%"><div class="s1isp7-3 cfbXfQ" src=""></div><img alt="Restaurant Card" class="s1isp7-5 bKaJwg" loading="lazy" src=""/></div><div class="sc-dHaUqb bljWID"><p class="sc-1hez2tp-0 sc-fcTNbh dNotRa">₹50 OFF</p></div></a><a class="sc-hdNmWC uicqY" href="/pune/zippyfeed-wakad/order"><div class="sc-kJdAmE dncqIB"><p class="sc-1hez2tp-0 sc-jBoNkH cqGniC">ZippyFeed</p></div><div class="sc-gkfylT ejPjnA"><div class="sc-2gamf4-0 fSJGVb" font-size="1.2rem" type="tag">NEWLY OPENED</div></div><p class="sc-1hez2tp-0 sc-fPbjcq dxJMBd">Fast Food, Rolls, Burger, Momos, Biryani</p><p class="sc-1hez2tp-0 sc-FAiZp gEhaLS"><span class="sc-dAWfgX gpTZdu">₹100 for one</span><span class="sc-fPEBxH ixrmsZ"></span>43 min</p></a><p class="sc-1hez2tp-0 sc-kQZOhr JuunF">Promoted</p><span class="sc-kSpkgE epusoB"> </span></div></div>,
#  <div class="jumbo-tracker"><div class="sc-jptPkM NRDZk"><a class="sc-ddcOto harCkj" href="/pune/theobroma-balewadi/order"><div class="s1isp7-1 gnNUmd sc-dzVpKk gkVhHs" height="24.8rem" width="100%"><div class="s1isp7-3 cfbXfQ" src=""></div><img alt="Restaurant Card" class="s1isp7-5 bKaJwg" loading="lazy" src=""/></div><div class="sc-dHaUqb bljWID"><p class="sc-1hez2tp-0 sc-fcTNbh dNotRa">₹50 OFF</p></div></a><a class="sc-hdNmWC uicqY" href="/pune/theobroma-balewadi/order"><div class="sc-kJdAmE dncqIB"><p class="sc-1hez2tp-0 sc-jBoNkH cqGniC">Theobroma</p></div><div class="sc-ghUbLI bqKqCV"><section class="lhdg1m-0 kqpxRE" value="4.4" width="max-content"><div class="lhdg1m-1 jgTktZ"><div class="lhdg1m-3 dAchCJ"><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18"  ...
#  <div class="jumbo-tracker"><div class="sc-jptPkM NRDZk"><a class="sc-ddcOto harCkj" href="/pune/wow-momo-baner/order"><div class="s1isp7-1 gnNUmd sc-dzVpKk gkVhHs" height="24.8rem" width="100%"><div class="s1isp7-3 cfbXfQ" src=""></div><img alt="Restaurant Card" class="s1isp7-5 bKaJwg" loading="lazy" src=""/></div><div class="sc-dHaUqb bljWID"><p class="sc-1hez2tp-0 sc-fcTNbh dNotRa">₹50 OFF</p></div></a><a class="sc-hdNmWC uicqY" href="/pune/wow-momo-baner/order"><div class="sc-kJdAmE dncqIB"><p class="sc-1hez2tp-0 sc-jBoNkH cqGniC">Wow! Momo</p></div><div class="sc-ghUbLI bqKqCV"><section class="lhdg1m-0 kqpxRE" value="3.9" width="max-content"><div class="lhdg1m-1 jgTktZ"><div class="lhdg1m-3 dAchCJ"><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-5 kDhJmF" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M16.6667 0H3.33333C1.5 0 0 1.5 0 3.33333V16.6667C0 18.5 1.5 20 3.33333 20H16.6667C18.5 20 20 18.5 20 16.6667V3.33333C20 1.5 18.5 0 16.6667 0ZM16.6667 8.75L13.5833 11.5L14.5 15.5833C14.5833 15.9167 14.5 16.1667 14.25 16.4167C14.1667 16.5 14 16.5833 13.8333 16.5833C13.6667 16.5833 13.5833 16.5833 13.4167 16.5L10 14.25L6.58333 16.3333C6.33333 16.5 6 16.5 5.75 16.3333C5.5 16.1667 5.41667 15.8333 5.5 15.5L6.41667 11.5L3.33333 8.75C3.08333 8.5 3 8.25 3.08333 7.91667C3.16667 7.66667 3.41667 7.41667 3.75 7.41667L7.75 7L9.33333 3.16667C9.41667 3 9.58333 2.83333 9.75 2.75C10.0833 2.58333 10.5833 2.75 10.6667 3.16667L12.25 7L16.25 7.33333C16.5833 7.33333 16.8333 7.58333 16.9167 7.83333C17 8.16667 16.9167 8.5 16.6667 8.75Z" fill-rule="evenodd"></path></svg></i><i class="rbbb40-1 MxLSp lhdg1m-6 HpiHL" color="#E23744" size="18"><svg aria-labelledby="icon-svg-title- icon-svg-desc-" class="rbbb40-0 ZGPg" fill="#E23744" height="18" role="img ...

# %%
len(data)
# Out:
# 9

# %%
atag
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-388743e78078> in <module>
# ----> 1 atag
#
# NameError: name 'atag' is not defined

# %%
from bs4 import BeautifulSoup

# %%
# Visit pyGuru on youTube


# importing modules
import requests
from bs4 import BeautifulSoup
import pandas as pd

# https://www.whoishostingthis.com/tools/user-agent/

city = input('Enter your city name : ')
url = 'https://www.zomato.com/'+city+'/top-restaurants'
header = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64; rv:78.0) Gecko/20100101 Firefox/78.0'}

response = requests.get(url,headers=header)
html = response.text

soup = BeautifulSoup(html,'lxml')
print(soup.title.text,'\n')

# scraping raw data and stroing it in a array

top_rest = soup.find_all('div',class_="bke1zw-0 cMipmx")
arr = []

for tr in top_rest:
	rsts = tr.find_all('div',class_="bke1zw-1")
	for i in rsts:
		name = i.select('a',class_='sc-muxYx sc-euitrJ hIVRVA')
		for k in name:
			arr.append(k.text)
	break

# print(arr)

# rearranging restaurant data in a single list

data = []
temp = [arr[0]]
for i in arr[1:]:
	if i.replace('.','',1).isdigit():
		data.append(temp)
		temp = [i]
	else:
		temp.append(i)

# print(data)

# strong different attributes in 4 lists

restraunts = []
address = []
cuisine = []
ratings = []

for lst in data:
	ratings.append(lst[0])
	restraunts.append(lst[1])
	address.append(lst[2])
	cuisine.append(','.join(lst[3:]))


header = ['Restraunt','Address','Cuisine','Ratings']
indices = [i for i in range(1,len(restraunts)+1)]
all_rests = zip(restraunts,address,cuisine,ratings)
df = pd.DataFrame(list(all_rests),index=indices,columns=header)
df.to_csv('Top restraunts in '+city+'.csv')
print(df)
# Out:
# Enter your city name : bangalore
# Top Restaurants in Bengaluru | Zomato
#
# Empty DataFrame
# Columns: [Restraunt, Address, Cuisine, Ratings]
# Index: []

# %%
city = input('Enter your city name : ')
url = 'https://www.zomato.com/pune/'+city+'-restaurants'
header = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64; rv:78.0) Gecko/20100101 Firefox/78.0'}

response = requests.get(url,headers=header)
html = response.text
print(url)
soup = BeautifulSoup(html,'lxml')
print(soup.title.text,'\n')
response = requests.get(url)
response
# Out:
# Enter your city name : baner
# https://www.zomato.com/pune/baner-restaurants
# Baner Restaurants, Pune, Restaurants in Baner - Zomato
# <Response [403]>

# %%
from urllib.request import Request, urlopen
import requests
url ='https://www.zomato.com/pune/baner-restaurants'
header={'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64; rv:78.0) Gecko/20100101 Firefox/78.0'}
res = requests.get(url,headers=header)

#webpage = urlopen(req).read()
res
#response = requests.get(url)
#response
# Out:
# <Response [200]>

# %%
pip install scrappy
# Out:
# Collecting scrappy
#   Using cached Scrappy-0.3.0.alpha.4.tar.gz (17 kB)
# Collecting guessit
#   Using cached guessit-3.3.1-py3-none-any.whl (160 kB)
# Collecting tvdb_api
#   Using cached tvdb_api-3.1.0.tar.gz (23 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ERROR: Could not find a version that satisfies the requirement hachoir-metadata (from scrappy) (from versions: none)
# ERROR: No matching distribution found for hachoir-metadata (from scrappy)
# Note: you may need to restart the kernel to use updated packages.

# %%
scrappy shell https://www.zomato.com/webroutes/search/home
# Out:
#   File "<ipython-input-2-d08fd9758f60>", line 1
#     scrappy shell https://www.zomato.com/webroutes/search/home
#             ^
# SyntaxError: invalid syntax

# %%
scrappy shell https://www.zomato.com/webroutes/search/home
# Out:
#   File "<ipython-input-47-d08fd9758f60>", line 1
#     scrappy shell https://www.zomato.com/webroutes/search/home
#             ^
# SyntaxError: invalid syntax

# %%
import scrapy
from scrapy.crawler import CrawlerProcess

class MarilynMansonQuotes(scrapy.Spider):
    name = "MarilynMansonQuotes"
    start_urls = [
        'https://en.wikiquote.org/wiki/Marilyn_Manson',
    ]
    
    def parse(self, response):
        for quote in response.css('div.mw-parser-output > ul > li'):
            yield {'quote': quote.extract()}

process = CrawlerProcess()
process.crawl(MarilynMansonQuotes)
process.start()

# %%
import requests
import json
records = []
for i in range(5):
    req = requests.get('https://www.zomato.com/pune/baner-restaurants'+str(i),
                       headers={'Accept': 'application/json',
    'Content-Type': 'application/json'})
    if(req.status_code == 200):
        josn2 = req.json()
        projects = josn2.get("projects") 
        for i in range(len(projects)):
            print("Project Name - " + projects[i]['name'],end='          Created By - ')
            print(projects[i]['creator'].get('name'))

        print("----------------")
