# %%
import pandas as pd

# %%
medi = pd.read_csv('Pune_Chemists_28_June_2021.csv')

# %%
medi= medi.drop(['S.No.'], axis = 1)

# %%
medi
# Out:
#                               Name  \
# 0                      Dev Medical
# 1                Happiness Forever
# 2                New Medical House
# 3                Prime Health Care
# 4                    Green Chemist
# ..                             ...
# 202                Jeevan Medicals
# 203                 Rathi Medicals
# 204  Shalaka Generic Medical Saw..
# 205                 Arihant Medico
# 206             Jan Aushadhi Store
#
#                                                Address         Phone  \
# 0    Kamal Heights Shop No. 6 Thergaon Pune - 41103...    7947219242
# 1    Survey No 6/2/22A Kharadi Pune - 411014 Opposi...    7947201730
# 2    Shop No 1 Ground Floor Laxmi Classic Building ...    7947206474
# 3    Vision Indra Megh Shop No. 6 &7 Near Lotus Bus...    7947369282
# 4    Shop No 12 and 3 Dewdale Society Dutta Mandir ...    7947198766
# ..                                                 ...           ...
# ...

# %%
medi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     207 non-null    object
#  1   Address  207 non-null    object
#  2   Phone    207 non-null    object
#  3   Website  207 non-null    object
# dtypes: object(4)
# memory usage: 6.6+ KB

# %%
code = ['411045','411007','411021','411057','412303','411017','411018','411027']

# %%
filtered = medi[medi['Address'].str.lower().str.contains('|'.join(code))]

# %%
filtered.reset_index(inplace = True, drop = True)
filtered
# Out:
#                              Name  \
# 0                   Green Chemist
# 1   Pride Medical and General S..
# 2                  Balaji Medical
# 3                 Jyotiba Medical
# 4   Arihant Medical and General..
# 5                  Sai Drug House
# 6                  Jyotiba Medico
# 7                Shravani Medical
# 8                  Sarthi Medical
# 9   Chaman Medical & General St..
# 10  Pooja Medical And General S..
# 11  Bharat Healthcare & Lifesty..
# 12            Life Point Pharmacy
# 13                    Health Plus
# 14  Wellness Forever Lifestyle ..
# 15                   Real Chemist
# 16  Aditya Birla Health Store (..
# 17               Medplus Pharmacy
# 18  Mediplus Chemists & Druggis..
# 19      24k Glitterati Apartments
# 20                Apollo Pharmacy
# 21    Medicare Chemist & Druggist
# 22    Medicare Chemist & Druggist
# 23             Fortis Healthworld
# 24                  Milan Medical
# 25                Maxwell Chemist
# ...

# %%
filtered.to_excel(r'Filtered_jd_medicals_data.xlsx', index = False)
